# %%
import tensorflow as tf
import os
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout,Input
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
data_dir = 'imagefolder'

# %%
data = tf.keras.utils.image_dataset_from_directory(
    'imagefolder',
    image_size=(256, 256)
)
# Out:
# Found 1060 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
batch = data_iterator.next()

# %%
dataset_size = data.cardinality().numpy()
train_size = int(dataset_size * 0.7)
val_size = int(dataset_size * 0.2)
test_size = int(dataset_size * 0.1)

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
model = Sequential()

# %%
model.add(Input(shape=(256,256,3)))
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(128, activation='relu')) 
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 304ms/step - accuracy: 0.5972 - loss: 0.8506 - val_accuracy: 0.8177 - val_loss: 0.4515
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 0.8282 - loss: 0.4612 - val_accuracy: 0.7760 - val_loss: 0.4819
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 0.8372 - loss: 0.3969 - val_accuracy: 0.8177 - val_loss: 0.3814
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - accuracy: 0.8418 - loss: 0.3637 - val_accuracy: 0.8698 - val_loss: 0.3666
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 0.8785 - loss: 0.3006 - val_accuracy: 0.8229 - val_loss: 0.4048
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 266ms/step - accuracy: 0.9027 - loss: 0.2599 - val_accuracy: 0.8021 - val_loss: 0.4167
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.8814 - loss: 0.2675 - val_accuracy: 0.8490 - val_loss: 0.3715
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - accuracy: 0.9199 - loss: 0.1809 - val_accuracy: 0.8802 - val_loss: 0.3155
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.9227 - loss: 0.1679 - val_accuracy: 0.8646 - val_loss: 0.3386
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 0.9659 - loss: 0.1278 - val_accuracy: 0.9115 - val_loss: 0.2609

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    ans = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %%
img = cv2.imread('garbage_pic.jpg')
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))

# %%
ans = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step

# %%
if ans < 0.5: 
    print(f'Predicted class is Non-Biodegradable')
else:
    print(f'Predicted class is Biodegradable')
# Out:
# Predicted class is Biodegradable

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('model','waste_classifier.keras'))

# %%
# new_model = load_model('path')
